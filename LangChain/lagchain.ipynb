# %%
import os
from dotenv import load_dotenv

load_dotenv(dotenv_path=".env", override=True)

os.environ['HF_TOKEN'] = os.getenv('HF_TOKEN')
os.environ['LANGSMITH_API_KEY'] = os.getenv('LANGSMITH_API_KEY')
os.environ['LANGSMITH_TRACING'] ='true'
os.environ['LANGSMITH_PROJECT'] = os.getenv('LANGSMITH_PROJECT')

print(os.environ['LANGSMITH_API_KEY'])
print(os.environ['LANGSMITH_PROJECT'])
# Out:
# Your_API_KEY
# Generative-AI application

# %%
from transformers import pipeline
from langchain_huggingface import HuggingFacePipeline
from langsmith.wrappers import wrap_gemini
from langsmith import traceable

@traceable
def model_response(input):
    # HuggingFace FLAN-T5 pipeline
    hf_pipeline = pipeline("text2text-generation", model="google/flan-t5-small", device=-1)

    llm = HuggingFacePipeline(
        pipeline=hf_pipeline
    )

    # Run a prompt (this triggers LangSmith tracing)
    response = llm.invoke(input)
    print(response)

# %%
response = model_response("What is AI?")
response
# Out:
# Device set to use cpu
# AI (disambiguation) AI may refer to:
